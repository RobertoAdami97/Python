# %% [markdown]
# # Git com Python - Automação de Tarefas

# %%
import pyautogui
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

# abrir o google chrome
navegador = webdriver.Chrome()
# logar no github
navegador.get("https://github.com/")
time.sleep(2)

navegador.find_element("xpath",'/html/body/div[1]/header/div/div[2]/div/div/div[2]/a').click()
time.sleep(2)
#navegador.find_element(By.CSS_SELECTOR, '[name="login"]').send_keys("webElement")
navegador.find_element("xpath",'//*[@id="login_field"]').send_keys("robertoadami@outlook.com")
navegador.find_element("xpath",'//*[@id="password"]').send_keys("Senha(12345)")
navegador.find_element("xpath",'//*[@id="login"]/div[4]/form/div/input[12]').click()
time.sleep(2)
navegador.find_element("xpath",'/html/body/div[5]/div/aside/div/div[1]/div/ul/li[1]/div/div/a').click()
time.sleep(2)
navegador.find_element("xpath",'//*[@id="repo-content-pjax-container"]/div/div/div[3]/div[1]/div[2]/span/get-repo/feature-callout/details/summary').click()
# selecionar o repositorio e copiar o link ssh
time.sleep(1)
link = navegador.find_element("xpath",'//*[@id="repo-content-pjax-container"]/div/div/div[3]/div[1]/div[2]/span/get-repo/feature-callout/details/div/div/div[1]/ul/li[1]/tab-container/div[2]/div/div/clipboard-copy').click()
# password: Senha(12345)
# abrir o git bash e executar os comandos para enviar os arquivos ao repositorio remoto
time.sleep(2)
pyautogui.press("winleft")
pyautogui.write("Git")
time.sleep(1)
pyautogui.press("space")
time.sleep(2)
pyautogui.write("Bash")
time.sleep(2)
pyautogui.press("enter")
time.sleep(6)
pyautogui.write("cd Desktop")
time.sleep(1.5)
pyautogui.press("enter")
time.sleep(1.5)
pyautogui.write("cd cursoPyton")
time.sleep(1.5)
pyautogui.press("enter")
time.sleep(1.5)
pyautogui.write("cd automacoesPython")
time.sleep(1.5)
pyautogui.press("enter")
