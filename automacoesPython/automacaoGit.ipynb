# %% [markdown]
# # Git com Python - Automação de Tarefas

# %%
import pyautogui
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

# abrir o google chrome
navegador = webdriver.Chrome()
# logar no github
navegador.get("https://github.com/")
time.sleep(1.5)

navegador.find_element("xpath",'/html/body/div[1]/header/div/div[2]/div/div/div[2]/a').click()
time.sleep(1.5)
#navegador.find_element(By.CSS_SELECTOR, '[name="login"]').send_keys("webElement")
navegador.find_element("xpath",'//*[@id="login_field"]').send_keys("robertoadami@outlook.com")
navegador.find_element("xpath",'//*[@id="password"]').send_keys("Senha(12345)")
navegador.find_element("xpath",'//*[@id="login"]/div[4]/form/div/input[11]').click()
time.sleep(1.5)
navegador.find_element("xpath",'/html/body/div[5]/div/aside/div/loading-context/div/div[1]/div/ul/li[1]/div/div/a').click()
# selecionar o repositorio e copiar o link ssh
time.sleep(1.5)
navegador.find_element("xpath",'/html/body/div[5]/div/main/turbo-frame/div/div/div/div[3]/div[1]/div[2]/span/get-repo/feature-callout/details/summary').click()
time.sleep(1.5)
navegador.find_element("xpath",'/html/body/div[5]/div/main/turbo-frame/div/div/div/div[3]/div[1]/div[2]/span/get-repo/feature-callout/details/div/div/div[1]/ul/li[1]/tab-container/div[2]/div/div/clipboard-copy').click()
# password: Senha(12345)
# abrir o git bash e executar os comandos para enviar os arquivos ao repositorio remoto
time.sleep(1.5)
pyautogui.press("winleft")
pyautogui.write("Git")
time.sleep(1.5)
pyautogui.press("space")
time.sleep(1.5)
pyautogui.write("Bash")
time.sleep(1.5)
pyautogui.press("enter")
time.sleep(1.5)
pyautogui.write("cd Desktop")
time.sleep(1.5)
pyautogui.press("enter")
time.sleep(1.5)
pyautogui.write("cd cursoPython")
time.sleep(1.5)
pyautogui.press("enter")
time.sleep(1.5)
pyautogui.write("cd automacoesPython")
time.sleep(1.5)
pyautogui.press("enter")
time.sleep(1.5)
pyautogui.write("git status")
time.sleep(1.5)
pyautogui.press("enter")
time.sleep(1.5)
pyautogui.write("git add automacaoGit.ipynb")
time.sleep(1.5)
pyautogui.press("enter")
time.sleep(1.5)
pyautogui.write("git commit -m automacaoGit")
time.sleep(1.5)
pyautogui.press("enter")
time.sleep(1.5)
pyautogui.write("git push")
time.sleep(1.5)
#pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
pyautogui.hotkey("alt","tab")
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# Input In [16], in <cell line: 24>()
#      20 #time.sleep(1.5)
#      21 #navegador.find_element("xpath",'/html/body/div[5]/div/aside/div/loading-context/div/div[1]/div/ul/li[1]/div/div/a').click()
#      22 # selecionar o repositorio e copiar o link ssh
#      23 time.sleep(1.5)
# ---> 24 navegador.find_element("xpath",'/html/body/div[5]/div/main/turbo-frame/div/div/div/div[3]/div[1]/div[2]/span/get-repo/feature-callout/details/div/div/div[1]/ul/li[1]/tab-container/div[2]/div/div/clipboard-copy').click()
#      25 # password: Senha(12345)
#      26 # abrir o git bash e executar os comandos para enviar os arquivos ao repositorio remoto
#      27 time.sleep(1.5)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webelement.py:88, in WebElement.click(self)
#      86 def click(self) -> None:
#      87     """Clicks the element."""
# ---> 88     self._execute(Command.CLICK_ELEMENT)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webelement.py:396, in WebElement._execute(self, command, params)
#     394     params = {}
#     395 params['id'] = self._id
# --> 396 return self._parent.execute(command, params)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py:428, in WebDriver.execute(self, driver_command, params)
#     426 response = self.command_executor.execute(driver_command, params)
#     427 if response:
# --> 428     self.error_handler.check_response(response)
#     429     response['value'] = self._unwrap_value(
#     430         response.get('value', None))
#     431     return response
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=105.0.5195.127)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00FBDF13+2219795]
# 	Ordinal0 [0x00F52841+1779777]
# 	Ordinal0 [0x00E64100+803072]
# 	Ordinal0 [0x00E93FB6+999350]
# 	Ordinal0 [0x00E89B76+957302]
# 	Ordinal0 [0x00EAE7FC+1107964]
# 	Ordinal0 [0x00E894B4+955572]
# 	Ordinal0 [0x00EAEA14+1108500]
# 	Ordinal0 [0x00EBF192+1175954]
# 	Ordinal0 [0x00EAE616+1107478]
# 	Ordinal0 [0x00E87F89+950153]
# 	Ordinal0 [0x00E88F56+954198]
# 	GetHandleVerifier [0x012B2CB2+3040210]
# 	GetHandleVerifier [0x012A2BB4+2974420]
# 	GetHandleVerifier [0x01056A0A+565546]
# 	GetHandleVerifier [0x01055680+560544]
# 	Ordinal0 [0x00F59A5C+1808988]
# 	Ordinal0 [0x00F5E3A8+1827752]
# 	Ordinal0 [0x00F5E495+1827989]
# 	Ordinal0 [0x00F680A4+1867940]
# 	BaseThreadInitThunk [0x7724FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77B47B5E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77B47B2E+238]
